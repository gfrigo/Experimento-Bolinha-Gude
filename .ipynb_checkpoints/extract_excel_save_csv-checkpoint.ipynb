# %% [markdown]
# # Física Experimental: Erros e Incertezas

# %% [markdown]
# `Nomes:`
# * Alice Vitória Boschetti
# * Felipe Cordeiro Carvalho
# * Gabriel Frigo Sena Silva
# * Joyce Nunes Alves
# * Eduardo Marques dos Santos
# * Kimberly Oliveira Germano Ribeiro

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

from IPython.display import Image

# %% [markdown]
# ## Dataframe

# %%
df = pd.read_excel('./data/measures_data.xlsx')
df.head()
# Out:
#       D1     D2
# 0  18.50  18.60
# 1  18.53  18.63
# 2  19.51  19.51
# 3  19.40  19.40
# 4  18.60  18.62

# %%
df.shape
# Out:
# (100, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   D1      100 non-null    float64
#  1   D2      100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
d_media_D1 = ((1/len(df))*(df['D1'].sum()))
d_media_D2 = ((1/len(df))*(df['D2'].sum()))

# %% [markdown]
# ## Coluna: Desvio absoluto

# %%
Image(filename='./pictures/desvio_absoluto.PNG')

# %%
df['desvio_absoluto_D1'] = df['D1'] - d_media
df['desvio_absoluto_D2'] = df['D2'] - d_media_D2
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2
# 0  18.50  18.60             -0.4607             -0.3413
# 1  18.53  18.63             -0.4307             -0.3113
# 2  19.51  19.51              0.5493              0.5687
# 3  19.40  19.40              0.4393              0.4587
# 4  18.60  18.62             -0.3607             -0.3213

# %% [markdown]
# ## Coluna: Desvio Médio

# %%
Image(filename='./pictures/desvio_medio.PNG')

# %%
df['desvio_quadrado_D1'] = df['desvio_absoluto_D1']**2
df['desvio_quadrado_D2'] = df['desvio_absoluto_D2']**2
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_quadrado_D1  \
# 0  18.50  18.60             -0.4607             -0.3413            0.212244
# 1  18.53  18.63             -0.4307             -0.3113            0.185502
# 2  19.51  19.51              0.5493              0.5687            0.301730
# 3  19.40  19.40              0.4393              0.4587            0.192984
# 4  18.60  18.62             -0.3607             -0.3213            0.130104
#
#    desvio_quadrado_D2
# 0            0.116486
# 1            0.096908
# 2            0.323420
# 3            0.210406
# 4            0.103234

# %%
df['desvio_quadrado_D1'] = df['desvio_quadrado_D1']/len(df)
df['desvio_quadrado_D2'] = df['desvio_quadrado_D2']/len(df)
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_quadrado_D1  \
# 0  18.50  18.60             -0.4607             -0.3413            0.002122
# 1  18.53  18.63             -0.4307             -0.3113            0.001855
# 2  19.51  19.51              0.5493              0.5687            0.003017
# 3  19.40  19.40              0.4393              0.4587            0.001930
# 4  18.60  18.62             -0.3607             -0.3213            0.001301
#
#    desvio_quadrado_D2
# 0            0.001165
# 1            0.000969
# 2            0.003234
# 3            0.002104
# 4            0.001032

# %%
df['desvio_medio_D1'] = df['desvio_quadrado_D1'].apply(math.sqrt)
df['desvio_medio_D2'] = df['desvio_quadrado_D2'].apply(math.sqrt)
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_quadrado_D1  \
# 0  18.50  18.60             -0.4607             -0.3413            0.002122
# 1  18.53  18.63             -0.4307             -0.3113            0.001855
# 2  19.51  19.51              0.5493              0.5687            0.003017
# 3  19.40  19.40              0.4393              0.4587            0.001930
# 4  18.60  18.62             -0.3607             -0.3213            0.001301
#
#    desvio_quadrado_D2  desvio_medio_D1  desvio_medio_D2
# 0            0.001165          0.04607          0.03413
# 1            0.000969          0.04307          0.03113
# 2            0.003234          0.05493          0.05687
# 3            0.002104          0.04393          0.04587
# 4            0.001032          0.03607          0.03213

# %%
df = df.drop(columns=['desvio_quadrado_D1','desvio_quadrado_D2'], axis=1)
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_medio_D1  \
# 0  18.50  18.60             -0.4607             -0.3413          0.04607
# 1  18.53  18.63             -0.4307             -0.3113          0.04307
# 2  19.51  19.51              0.5493              0.5687          0.05493
# 3  19.40  19.40              0.4393              0.4587          0.04393
# 4  18.60  18.62             -0.3607             -0.3213          0.03607
#
#    desvio_medio_D2
# 0          0.03413
# 1          0.03113
# 2          0.05687
# 3          0.04587
# 4          0.03213

# %% [markdown]
# ## Volume

# %% [markdown]
# `Fórmula:` V = 4/3 π r³:
#
# * V = volume;
# * r = raio.

# %%
df['volume_D1'] = ((4/3)*math.pi)*((df['D1']/2)**3)
df['volume_D2'] = ((4/3)*math.pi)*((df['D2']/2)**3)
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_medio_D1  \
# 0  18.50  18.60             -0.4607             -0.3413          0.04607
# 1  18.53  18.63             -0.4307             -0.3113          0.04307
# 2  19.51  19.51              0.5493              0.5687          0.05493
# 3  19.40  19.40              0.4393              0.4587          0.04393
# 4  18.60  18.62             -0.3607             -0.3213          0.03607
#
#    desvio_medio_D2    volume_D1    volume_D2
# 0          0.03413  3315.231098  3369.282723
# 1          0.03113  3331.385417  3385.612013
# 2          0.05687  3888.395488  3888.395488
# 3          0.04587  3822.995723  3822.995723
# 4          0.03213  3369.282723  3380.163068

# %% [markdown]
# #### Volume desvio absoluto

# %%
v_media_D1 = ((1/len(df))*(df['volume_D1'].sum()))
v_media_D2 = ((1/len(df))*(df['volume_D2'].sum()))

df['desvio_absoluto_D1_vol'] = df['D1'] - v_media_D1
df['desvio_absoluto_D2_vol'] = df['D2'] - v_media_D2
df.head()
# Out:
#       D1     D2  desvio_absoluto_D1  desvio_absoluto_D2  desvio_medio_D1  \
# 0  18.50  18.60             -0.4607             -0.3413          0.04607
# 1  18.53  18.63             -0.4307             -0.3113          0.04307
# 2  19.51  19.51              0.5493              0.5687          0.05493
# 3  19.40  19.40              0.4393              0.4587          0.04393
# 4  18.60  18.62             -0.3607             -0.3213          0.03607
#
#    desvio_medio_D2    volume_D1    volume_D2  desvio_absoluto_D1_vol  \
# 0          0.03413  3315.231098  3369.282723            -3560.121396
# 1          0.03113  3331.385417  3385.612013            -3560.091396
# 2          0.05687  3888.395488  3888.395488            -3559.111396
# 3          0.04587  3822.995723  3822.995723            -3559.221396
# 4          0.03213  3369.282723  3380.163068            -3560.021396
#
#    desvio_absoluto_D2_vol
# 0             -3548.92509
# 1             -3548.89509
# 2             -3548.01509
# ...

# %% [markdown]
# #### Volume desvio médio
